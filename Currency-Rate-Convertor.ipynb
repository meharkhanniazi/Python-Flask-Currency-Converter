# %%
import requests

# %%
response = requests.get('https://v6.exchangerate-api.com/v6/cb456cf692ff5e86da9404ff/latest/USD')

# %%
response.status_code
# Out:
# 200

# %%
dir(response)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
response.json()['conversion_rates']['PKR']
# Out:
# 281.0364

# %%
response.json()
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1705017602,
#  'time_last_update_utc': 'Fri, 12 Jan 2024 00:00:02 +0000',
#  'time_next_update_unix': 1705104002,
#  'time_next_update_utc': 'Sat, 13 Jan 2024 00:00:02 +0000',
#  'base_code': 'USD',
#  'conversion_rates': {'USD': 1,
#   'AED': 3.6725,
#   'AFN': 71.0998,
#   'ALL': 95.4936,
#   'AMD': 405.441,
#   'ANG': 1.79,
#   'AOA': 842.8835,
#   'ARS': 815.45,
#   'AUD': 1.4936,
#   'AWG': 1.79,
#   'AZN': 1.7002,
#   'BAM': 1.783,
#   'BBD': 2.0,
#   'BDT': 109.6241,
#   'BGN': 1.7827,
#   'BHD': 0.376,
#   'BIF': 2842.5535,
#   'BMD': 1.0,
#   'BND': 1.3309,
#   'BOB': 6.8333,
#   'BRL': 4.8834,
#   'BSD': 1.0,
#   'BTN': 83.0824,
#   'BWP': 13.5866,
#   'BYN': 3.2075,
#   'BZD': 2.0,
#   'CAD': 1.3382,
#   'CDF': 2693.8123,
#   'CHF': 0.8515,
#   'CLP': 910.2505,
#   'CNY': 7.1676,
#   'COP': 3972.3326,
# ...
